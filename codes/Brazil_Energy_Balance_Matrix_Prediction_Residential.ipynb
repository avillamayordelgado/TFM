# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the file
file_path = "C:/Users/ramon/Documents/MASTER BIG DATA & DATA SCIENCE/TFM/Nueva carpeta/TFM-main/datas/Option_B/Brazil_Energy balance matrix.xlsx"

#File excel with multi-sheet_names is read as an Dictionary
Dict = pd.read_excel(file_path, sheet_name=None, skiprows=range(4), skipfooter=3)

for k in Dict.keys():       
    # Round the values of each column in dataframe with 2 decimals
    Dict[k]=Dict[k].applymap(lambda x: round(x, 2) if isinstance(x, (int, float)) else x)
    
    #Ignor the first row (unit) in each df
    Dict[k]=Dict[k][1:]
    
    #Rename of columns in df
    Dict[k].rename(columns={'Unnamed: 0': 'SECTOR','OTHER PRIMARY_x000d_\n':'OTHER PRIMARY'}, inplace=True)   
    
print(Dict.keys())

# Convert the keys of Dict to only contain the year
for k in list(Dict.keys()):
    k_new = k.split(' - ')[0]
    Dict[k_new] = Dict.pop(k)
    
    Dict[k_new]["Year"]=k_new
        
print('\n')
print(Dict.keys())



#Save the Clean Dictionary in Excel with multi-sheet_names
file_path="C:/Users/ramon/Documents/MASTER BIG DATA & DATA SCIENCE/TFM/Nueva carpeta/TFM-main/datas/Option_B/Brazil_Energy balance matrix_cleaned.xlsx"
with pd.ExcelWriter(file_path) as writer:
    for k, df in Dict.items():
        df.to_excel(writer, sheet_name=k)

df_2021=Dict['2021']
df_2021.tail(14)
# Out:
# dict_keys(['1970 - Brazil', '1971 - Brazil', '1972 - Brazil', '1973 - Brazil', '1974 - Brazil', '1975 - Brazil', '1976 - Brazil', '1977 - Brazil', '1978 - Brazil', '1979 - Brazil', '1980 - Brazil', '1981 - Brazil', '1982 - Brazil', '1983 - Brazil', '1984 - Brazil', '1985 - Brazil', '1986 - Brazil', '1987 - Brazil', '1988 - Brazil', '1989 - Brazil', '1990 - Brazil', '1991 - Brazil', '1992 - Brazil', '1993 - Brazil', '1994 - Brazil', '1995 - Brazil', '1996 - Brazil', '1997 - Brazil', '1998 - Brazil', '1999 - Brazil', '2000 - Brazil', '2001 - Brazil', '2002 - Brazil', '2003 - Brazil', '2004 - Brazil', '2005 - Brazil', '2006 - Brazil', '2007 - Brazil', '2008 - Brazil', '2009 - Brazil', '2010 - Brazil', '2011 - Brazil', '2012 - Brazil', '2013 - Brazil', '2014 - Brazil', '2015 - Brazil', '2016 - Brazil', '2017 - Brazil', '2018 - Brazil', '2019 - Brazil', '2020 - Brazil', '2021 - Brazil'])
#
#
# dict_keys(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'])
#                                 SECTOR      OIL NATURAL GAS      COAL  \
# 14                       OTHER CENTERS  -734.46         NaN       NaN
# 15                TOTAL TRANSFORMATION -93286.2   -20068.66 -12255.29
# 16                     OWN CONSUMPTION      NaN     4706.08       NaN
# 17                              LOSSES      NaN      241.54      17.9
# 18                          ADJUSTMENT    54.58      -55.21      0.49
# 19                          TRANSPORT       NaN      1903.2       NaN
# 20                          INDUSTRIAL      NaN     8417.91   3497.42
# 21                         RESIDENTIAL      NaN      454.97       NaN
# 22        COMMERCIAL, SERVICES, PUBLIC      NaN      136.77       NaN
# 23     AGRICULTURE, FISHING AND MINING      NaN      261.08    146.11
# 24             CONSTRUCTION AND OTHERS      NaN         NaN       NaN
# 25                  ENERGY CONSUMPTION      NaN    11173.92   3643.53
# 26              NON-ENERGY CONSUMPTION      NaN      215.94       NaN
# 27                   FINAL CONSUMPTION      NaN    11389.86   3643.53
#
#    HYDROENERGY GEOTHERMAL  NUCLEAR  FIREWOOD SUGARCANE AND PRODUCTS  \
# 14         NaN        NaN      NaN       NaN                    NaN
# 15   -31125.01        NaN -3835.75  -7775.51              -21164.15
# 16         NaN        NaN      NaN       NaN                12887.1
# 17         NaN        NaN      NaN       NaN                    NaN
# 18         0.0        NaN      NaN       NaN                    0.0
# 19         NaN        NaN      NaN       NaN                    NaN
# 20         NaN        NaN      NaN   7588.34                15418.5
# 21         NaN        NaN      NaN   7422.22                    NaN
# 22         NaN        NaN      NaN     81.99                    NaN
# 23         NaN        NaN      NaN    3149.9                    NaN
# 24         NaN        NaN      NaN       NaN                    NaN
# 25         NaN        NaN      NaN  18242.44                15418.5
# 26         NaN        NaN      NaN       NaN                    NaN
# 27         NaN        NaN      NaN  18242.44                15418.5
#
#    OTHER PRIMARY  ... DIESEL OIL FUEL OIL     COKE CHARCOAL    GASES  \
# 14       -5589.7  ...    5723.21      NaN      NaN      NaN      NaN
# 15     -18575.13  ...   -1933.18 -1881.81      NaN      NaN  -394.47
# 16           NaN  ...     509.02   131.89      NaN      NaN   205.16
# 17           NaN  ...        NaN      NaN     41.3    57.86      NaN
# 18         -0.05  ...     -50.87    -0.43      0.0      0.0   -22.68
# 19           NaN  ...    42980.4   776.88      NaN      NaN      NaN
# 20       8568.38  ...     785.48  1383.83  7850.75  3359.75  1326.98
# 21        716.94  ...        NaN      NaN      NaN   411.72      NaN
# 22        176.91  ...      43.85     23.4      NaN    76.99      NaN
# 23           NaN  ...    7461.33    98.82    32.48     9.11      NaN
# 24           NaN  ...        NaN      NaN      NaN      NaN      NaN
# 25       9462.23  ...   51271.06  2282.93  7883.22  3857.57  1326.98
# 26           NaN  ...        NaN      NaN      NaN      NaN   156.21
# 27       9462.23  ...   51271.06  2282.93  7883.22  3857.57  1483.19
#
#    OTHER SECONDARY NON-ENERGY TOTAL SECUNDARIES      TOTAL  Year
# 14         1580.88    -233.26           7431.85     -991.3  2021
# 15        -1906.82    -233.26          -8215.28  -26510.47  2021
# 16         3078.97        NaN           7258.66   24851.84  2021
# 17             NaN        NaN            9456.1    9715.53  2021
# 18           28.88      89.41            130.32     130.14  2021
# 19             NaN        NaN           83272.9    85176.1  2021
# 20         5931.98        NaN          38899.12   82389.66  2021
# 21             NaN        NaN          19827.62   28421.75  2021
# 22             NaN        NaN          12152.68   12548.34  2021
# 23          196.57        NaN           11864.6   15421.69  2021
# 24             NaN        NaN               NaN        NaN  2021
# 25         6128.55        NaN         166016.93  223957.54  2021
# 26             NaN    6626.69          13021.03   13236.97  2021
# 27         6128.55    6626.69         179037.96  237194.52  2021
#
# [14 rows x 25 columns]

# %%
df_2021.SECTOR
# Out:
# 1                                     PRODUCTION
# 2                                         IMPORT
# 3                                         EXPORT
# 4                                   STOCK CHANGE
# 5                                         UNUSED
# 6                                   TOTAL SUPPLY
# 7                                     REFINERIES
# 8                                  POWER PLANTS
# 9                                 SELF-PRODUCERS
# 10                                    GAS PLANTS
# 11                               CHARCOAL PLANTS
# 12       COKE PLANTS AND BLAST FURNACES_x000d_\n
# 13                                  DISTILLERIES
# 14                                 OTHER CENTERS
# 15                          TOTAL TRANSFORMATION
# 16                               OWN CONSUMPTION
# 17                                        LOSSES
# 18                                    ADJUSTMENT
# 19                                    TRANSPORT
# 20                                    INDUSTRIAL
# 21                                   RESIDENTIAL
# 22                  COMMERCIAL, SERVICES, PUBLIC
# 23               AGRICULTURE, FISHING AND MINING
# 24                       CONSTRUCTION AND OTHERS
# 25                            ENERGY CONSUMPTION
# 26                        NON-ENERGY CONSUMPTION
# 27                             FINAL CONSUMPTION
# Name: SECTOR, dtype: object

# %%
df_2021
# Out:
#                                         SECTOR        OIL NATURAL GAS  \
# 1                                   PRODUCTION  152713.43    26371.48
# 2                                       IMPORT    7359.21    14796.23
# 3                                       EXPORT   65724.07         NaN
# 4                                 STOCK CHANGE   -1007.78    -3598.93
# 5                                       UNUSED        NaN     1217.87
# 6                                 TOTAL SUPPLY   93340.78    36350.92
# 7                                   REFINERIES  -92551.74         NaN
# 8                                POWER PLANTS         NaN    -13219.0
# 9                               SELF-PRODUCERS        NaN    -4266.04
# 10                                  GAS PLANTS        NaN    -2583.62
# 11                             CHARCOAL PLANTS        NaN         NaN
# 12     COKE PLANTS AND BLAST FURNACES_x000d_\n        NaN         NaN
# 13                                DISTILLERIES        NaN         NaN
# 14                               OTHER CENTERS    -734.46         NaN
# 15                        TOTAL TRANSFORMATION   -93286.2   -20068.66
# 16                             OWN CONSUMPTION        NaN     4706.08
# 17                                      LOSSES        NaN      241.54
# 18                                  ADJUSTMENT      54.58      -55.21
# 19                                  TRANSPORT         NaN      1903.2
# 20                                  INDUSTRIAL        NaN     8417.91
# 21                                 RESIDENTIAL        NaN      454.97
# 22                COMMERCIAL, SERVICES, PUBLIC        NaN      136.77
# 23             AGRICULTURE, FISHING AND MINING        NaN      261.08
# 24                     CONSTRUCTION AND OTHERS        NaN         NaN
# 25                          ENERGY CONSUMPTION        NaN    11173.92
# 26                      NON-ENERGY CONSUMPTION        NaN      215.94
# 27                           FINAL CONSUMPTION        NaN    11389.86
#
#         COAL HYDROENERGY GEOTHERMAL  NUCLEAR  FIREWOOD SUGARCANE AND PRODUCTS  \
# 1    2633.08    31125.01        NaN  3835.75  26017.95               49469.74
# 2   13216.31         NaN        NaN      NaN       NaN                    NaN
# 3        NaN         NaN        NaN      NaN       NaN                    NaN
# 4      67.82         NaN        NaN      NaN       NaN                    NaN
# 5        NaN         NaN        NaN      NaN       NaN                    NaN
# 6   15917.21    31125.01        NaN  3835.75  26017.95               49469.74
# 7        NaN         NaN        NaN      NaN       NaN                    NaN
# 8   -4189.67   -29752.22        NaN -3835.75    -56.11                    NaN
# 9    -215.78    -1372.79        NaN      NaN   -373.38               -5782.78
# 10       NaN         NaN        NaN      NaN       NaN                    NaN
# 11       NaN         NaN        NaN      NaN  -7346.03                    NaN
# 12  -7849.84         NaN        NaN      NaN       NaN                    NaN
# 13       NaN         NaN        NaN      NaN       NaN              -15381.37
# 14       NaN         NaN        NaN      NaN       NaN                    NaN
# 15 -12255.29   -31125.01        NaN -3835.75  -7775.51              -21164.15
# 16       NaN         NaN        NaN      NaN       NaN                12887.1
# 17      17.9         NaN        NaN      NaN       NaN                    NaN
# 18      0.49         0.0        NaN      NaN       NaN                    0.0
# 19       NaN         NaN        NaN      NaN       NaN                    NaN
# 20   3497.42         NaN        NaN      NaN   7588.34                15418.5
# 21       NaN         NaN        NaN      NaN   7422.22                    NaN
# 22       NaN         NaN        NaN      NaN     81.99                    NaN
# 23    146.11         NaN        NaN      NaN    3149.9                    NaN
# 24       NaN         NaN        NaN      NaN       NaN                    NaN
# 25   3643.53         NaN        NaN      NaN  18242.44                15418.5
# 26       NaN         NaN        NaN      NaN       NaN                    NaN
# 27   3643.53         NaN        NaN      NaN  18242.44                15418.5
#
#    OTHER PRIMARY  ... DIESEL OIL  FUEL OIL     COKE CHARCOAL    GASES  \
# 1       28037.32  ...   41972.43  16109.25  6866.86  3915.43  2060.14
# 2            NaN  ...   12211.92    581.74  1150.16      NaN      NaN
# 3            NaN  ...      499.3  11963.08      NaN      NaN      NaN
# 4            NaN  ...     -22.66   -431.71    -92.5      NaN      NaN
# 5            NaN  ...        NaN       NaN      NaN      NaN      NaN
# 6       28037.32  ...   53662.39    4296.2  7924.52  3915.43  2060.14
# 7            NaN  ...   36249.21  16109.25      NaN      NaN      NaN
# 8       -7138.42  ...   -1371.21  -1656.49      NaN      NaN      NaN
# 9       -5688.41  ...    -561.98   -225.32      NaN      NaN  -394.47
# 10           NaN  ...        NaN       NaN      NaN      NaN      NaN
# 11           NaN  ...        NaN       NaN      NaN  3915.43      NaN
# 12           NaN  ...        NaN       NaN  6866.86      NaN  2060.14
# 13       -158.61  ...        NaN       NaN      NaN      NaN      NaN
# 14       -5589.7  ...    5723.21       NaN      NaN      NaN      NaN
# 15     -18575.13  ...   -1933.18  -1881.81      NaN      NaN  -394.47
# 16           NaN  ...     509.02    131.89      NaN      NaN   205.16
# 17           NaN  ...        NaN       NaN     41.3    57.86      NaN
# 18         -0.05  ...     -50.87     -0.43      0.0      0.0   -22.68
# 19           NaN  ...    42980.4    776.88      NaN      NaN      NaN
# 20       8568.38  ...     785.48   1383.83  7850.75  3359.75  1326.98
# 21        716.94  ...        NaN       NaN      NaN   411.72      NaN
# 22        176.91  ...      43.85      23.4      NaN    76.99      NaN
# 23           NaN  ...    7461.33     98.82    32.48     9.11      NaN
# 24           NaN  ...        NaN       NaN      NaN      NaN      NaN
# 25       9462.23  ...   51271.06   2282.93  7883.22  3857.57  1326.98
# 26           NaN  ...        NaN       NaN      NaN      NaN   156.21
# 27       9462.23  ...   51271.06   2282.93  7883.22  3857.57  1483.19
#
#    OTHER SECONDARY NON-ENERGY TOTAL SECUNDARIES      TOTAL  Year
# 1          9109.18    5630.96         189790.51  320203.76  2021
# 2          2901.18    1712.36           31674.9   67046.66  2021
# 3           841.83     385.76          17331.46   83055.53  2021
# 4           -25.31       -8.2            -35.62   -4574.51  2021
# 5              NaN        NaN               NaN    1217.87  2021
# 6         11143.23    6949.36         204098.32   298402.5  2021
# 7           7528.3    4710.47          95389.98    2838.23  2021
# 8            -75.3        NaN           46508.5  -14785.66  2021
# 9           -551.3        NaN           9776.97   -9655.28  2021
# 10             NaN     920.49           2354.08    -229.54  2021
# 11             NaN        NaN           3915.43   -3430.59  2021
# 12        -1280.22        NaN            8927.0    -203.06  2021
# 13             NaN        NaN          15486.71     -53.26  2021
# 14         1580.88    -233.26           7431.85     -991.3  2021
# 15        -1906.82    -233.26          -8215.28  -26510.47  2021
# 16         3078.97        NaN           7258.66   24851.84  2021
# 17             NaN        NaN            9456.1    9715.53  2021
# 18           28.88      89.41            130.32     130.14  2021
# 19             NaN        NaN           83272.9    85176.1  2021
# 20         5931.98        NaN          38899.12   82389.66  2021
# 21             NaN        NaN          19827.62   28421.75  2021
# 22             NaN        NaN          12152.68   12548.34  2021
# 23          196.57        NaN           11864.6   15421.69  2021
# 24             NaN        NaN               NaN        NaN  2021
# 25         6128.55        NaN         166016.93  223957.54  2021
# 26             NaN    6626.69          13021.03   13236.97  2021
# 27         6128.55    6626.69         179037.96  237194.52  2021
#
# [27 rows x 25 columns]

# %%
Dict2=Dict.copy()

for k in Dict2.keys():
   # selected_columns = ['SECTOR', 'OIL', 'NATURAL GAS', 'COAL', 'HYDROENERGY', 'GEOTHERMAL',
    #   'NUCLEAR', 'FIREWOOD', 'SUGARCANE AND PRODUCTS', 'OTHER PRIMARY', 'TOTAL PRIMARIES','Year']
    selected_columns = ['SECTOR','TOTAL','Year']
    Dict2[k]=Dict2[k][selected_columns]
    selected_rows=['   RESIDENTIAL','FINAL CONSUMPTION']
    Dict2[k]=Dict2[k][Dict2[k]['SECTOR'].isin(selected_rows)]
    
    # Concatenate all DataFrames in Dict vertically
    df_conc = pd.concat(Dict2.values(), ignore_index=True)
    
    # Move the column "Year" to the first position
    last_column_name = df_conc.columns[-1]
    # Reorder the columns by concatenating the last column with the rest of the DataFrame
    df_conc = pd.concat([df_conc[last_column_name], df_conc.drop(columns=last_column_name)], axis=1) # Datafames of TOTAL SUPPLY
    df_conc.set_index("Year", inplace=True)
    df_conc.index = df_conc.index.astype(int)
    #df_TC1=df_conc.drop(columns="SECTOR")
    # Set the value "NaN" by Zero
    df_TC1 = df_conc.apply(lambda column: column.fillna(0))
    

df_TC1
# Out:
#                  SECTOR      TOTAL
# Year
# 1970        RESIDENTIAL   22075.66
# 1970  FINAL CONSUMPTION   58834.12
# 1971        RESIDENTIAL   22253.96
# 1971  FINAL CONSUMPTION   61691.69
# 1972        RESIDENTIAL   22440.87
# ...                 ...        ...
# 2019  FINAL CONSUMPTION  230298.05
# 2020        RESIDENTIAL   28199.70
# 2020  FINAL CONSUMPTION  226959.77
# 2021        RESIDENTIAL   28421.75
# 2021  FINAL CONSUMPTION  237194.52
#
# [104 rows x 2 columns]

# %%
# Group by Year and SECTOR, and sum the TOTAL values
grouped_df = df_TC1.groupby(['Year', 'SECTOR'])['TOTAL'].sum().reset_index()

# Pivot the data
pivot_df = grouped_df.pivot(index='Year', columns='SECTOR', values='TOTAL')

# Display the result
pivot_df.head()
# Out:
# SECTOR     RESIDENTIAL  FINAL CONSUMPTION
# Year
# 1970          22075.66           58834.12
# 1971          22253.96           61691.69
# 1972          22440.87           65995.12
# 1973          22354.13           71692.86
# 1974          22316.70           76198.40

# %%
pivot_df.columns = pivot_df.columns.str.strip()

# %%
pivot_df['RESIDENTIAL/FC'] = pivot_df['RESIDENTIAL'] / pivot_df['FINAL CONSUMPTION']

# %%
pivot_df['RESIDENTIAL/FC'].fillna(0, inplace=True)

# %%
pivot_df
# Out:
# SECTOR  RESIDENTIAL  FINAL CONSUMPTION  RESIDENTIAL/FC
# Year
# 1970       22075.66           58834.12        0.375219
# 1971       22253.96           61691.69        0.360729
# 1972       22440.87           65995.12        0.340038
# 1973       22354.13           71692.86        0.311804
# 1974       22316.70           76198.40        0.292876
# 1975       22048.77           78491.85        0.280905
# 1976       21936.82           83208.97        0.263635
# 1977       21413.34           85026.52        0.251843
# 1978       20820.41           88944.97        0.234082
# 1979       20984.85           93782.10        0.223762
# 1980       20956.91           94534.85        0.221684
# 1981       20721.25           91232.82        0.227125
# 1982       19454.17           92462.42        0.210401
# 1983       18867.12           92200.73        0.204631
# 1984       19170.37           95222.32        0.201322
# 1985       18546.37           99634.71        0.186144
# 1986       17915.84          105251.29        0.170220
# 1987       18850.37          108807.69        0.173245
# 1988       18705.65          109756.68        0.170428
# 1989       18509.64          111486.58        0.166026
# 1990       19385.13          114351.06        0.169523
# 1991       19662.82          115475.10        0.170278
# 1992       19883.99          116856.28        0.170158
# 1993       19026.64          120002.68        0.158552
# 1994       18969.79          126260.73        0.150243
# 1995       19055.10          131516.33        0.144888
# 1996       19587.21          138211.73        0.141719
# 1997       19321.80          143104.84        0.135018
# 1998       19944.07          147985.31        0.134771
# 1999       21290.65          155221.98        0.137163
# 2000       21715.90          156808.59        0.138487
# 2001       21227.36          156515.30        0.135625
# 2002       20845.18          159678.14        0.130545
# 2003       21055.25          161359.72        0.130486
# 2004       21304.79          170298.70        0.125102
# 2005       21730.10          173105.86        0.125531
# 2006       22034.81          178276.74        0.123599
# 2007       22216.18          189140.88        0.117458
# 2008       22681.60          195412.94        0.116070
# 2009       23071.27          190814.83        0.120909
# 2010       23610.56          207712.48        0.113669
# 2011       23209.47          214859.53        0.108022
# 2012       23752.93          229774.08        0.103375
# 2013       23723.46          233713.25        0.101507
# 2014       24778.75          237763.12        0.104216
# 2015       24943.13          232537.06        0.107265
# 2016       24791.96          228653.04        0.108426
# 2017       25356.57          233004.63        0.108824
# 2018       26377.98          228665.38        0.115356
# 2019       26589.02          230298.05        0.115455
# 2020       28199.70          226959.77        0.124250
# 2021       28421.75          237194.52        0.119825

# %%
media = pivot_df['RESIDENTIAL/FC'].mean()
desviacion_tipica = pivot_df['RESIDENTIAL/FC'].std()
moda = pivot_df['RESIDENTIAL/FC'].mode().iloc[0] # La moda puede tener más de un valor, así que tomamos el primero
mediana = pivot_df['RESIDENTIAL/FC'].median()

print("La media de RESIDENTIAL/FC es:", media)
print("La desviación típica de RESIDENTIAL/FC es:", desviacion_tipica)
print("La moda de RESIDENTIAL/FC es:", moda)
print("La mediana de RESIDENTIAL/FC es:", mediana)
# Out:
# La media de RESIDENTIAL/FC es: 0.17254678747871052
# La desviación típica de RESIDENTIAL/FC es: 0.07065500508978646
# La moda de RESIDENTIAL/FC es: 0.10150669677478705
# La mediana de RESIDENTIAL/FC es: 0.1433032897409529

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Suponiendo que tus datos estén en orden cronológico
X = np.arange(len(pivot_df)).reshape(-1, 1)
y = pivot_df['RESIDENTIAL/FC'].values

model = LinearRegression()
model.fit(X, y)

# Prediciendo 20 puntos en el futuro
X_future = np.arange(len(pivot_df), len(pivot_df) + 20).reshape(-1, 1)
predictions = model.predict(X_future)

print("Predicciones para los próximos 20 años:", predictions)
# Out:
# Predicciones para los próximos 20 años: [ 0.06209486  0.05792687  0.05375887  0.04959087  0.04542288  0.04125488
#   0.03708688  0.03291888  0.02875089  0.02458289  0.02041489  0.0162469
#   0.0120789   0.0079109   0.0037429  -0.00042509 -0.00459309 -0.00876109
#  -0.01292908 -0.01709708]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Suponiendo que tus datos estén en orden cronológico
X = np.arange(len(pivot_df)).reshape(-1, 1)
y = pivot_df['RESIDENTIAL/FC'].values

model = LinearRegression()
model.fit(X, y)

# Prediciendo 20 puntos en el futuro
X_future = np.arange(len(pivot_df), len(pivot_df) + 20).reshape(-1, 1)
predictions = model.predict(X_future)

# Gráfico de los datos actuales
plt.plot(X, y, label="Datos Actuales")

# Gráfico de las predicciones
plt.plot(X_future, predictions, label="Predicciones a 20 años", linestyle='dashed')

plt.xlabel("Tiempo")
plt.ylabel("RESIDENTIAL/FC")
plt.legend()
plt.title("Predicción a 20 años de RESIDENTIAL/FC")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Asumiendo que tus datos están en orden cronológico y son estacionarios
y = pivot_df['RESIDENTIAL/FC'].values

# Ajustando el modelo ARIMA
# Puedes ajustar los parámetros p, d, q según tu serie temporal
model = ARIMA(y, order=(5,1,0))
fit_model = model.fit()

# Haciendo una predicción para los próximos 20 puntos
forecast = fit_model.forecast(steps=20)

# Gráfico de los datos actuales
plt.plot(y, label="Datos Actuales")

# Gráfico de las predicciones
plt.plot(range(len(y), len(y) + 20), forecast, label="Predicciones a 20 años", linestyle='dashed')

plt.xlabel("Tiempo")
plt.ylabel("RESIDENTIAL/FC")
plt.legend()
plt.title("Predicción a 20 años de INDUSTRIAL/FC con ARIMA")
plt.show()

# %% [markdown]
# 1. Modelo de Suavizado Exponencial (Exponential Smoothing)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

model = ExponentialSmoothing(y, trend='add')
fit_model = model.fit()

forecast = fit_model.forecast(steps=20)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), forecast, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %% [markdown]
# 3. Modelo de Regresión Polinomial

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)

X_future_poly = poly.transform(X_future)
predictions = model.predict(X_future_poly)

plt.plot(X, y, label="Datos Actuales")
plt.plot(X_future, predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X, y)
predictions = lasso_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import Ridge

ridge_model = Ridge(alpha=0.1)
ridge_model.fit(X, y)
predictions = ridge_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import ElasticNet

elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_model.fit(X, y)
predictions = elastic_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Puedes ajustar los parámetros de estacionalidad según tus datos
model = SARIMAX(y, order=(5, 1, 0), seasonal_order=(0, 1, 1, 12))
fit_model = model.fit()

forecast = fit_model.get_forecast(steps=20)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), forecast.predicted_mean, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()
# Out:
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'

# %% [markdown]
# **Suavizado Exponencial Estado-Espacio (ETS)**

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Ajusta el modelo ETS
ets_model = ExponentialSmoothing(y, trend='add', seasonal='add', seasonal_periods=12)
fit_model = ets_model.fit()

# Predicción a 20 años
forecast = fit_model.forecast(steps=20)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), forecast, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
pip install arch
# Out:
# Requirement already satisfied: arch in c:\users\ramon\anaconda3\lib\site-packages (6.1.0)
# Requirement already satisfied: statsmodels>=0.12 in c:\users\ramon\anaconda3\lib\site-packages (from arch) (0.13.2)
# Requirement already satisfied: pandas>=1.1 in c:\users\ramon\anaconda3\lib\site-packages (from arch) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\ramon\anaconda3\lib\site-packages (from arch) (1.21.5)
# Requirement already satisfied: scipy>=1.5 in c:\users\ramon\anaconda3\lib\site-packages (from arch) (1.7.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramon\anaconda3\lib\site-packages (from pandas>=1.1->arch) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ramon\anaconda3\lib\site-packages (from pandas>=1.1->arch) (2.8.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ramon\anaconda3\lib\site-packages (from statsmodels>=0.12->arch) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\ramon\anaconda3\lib\site-packages (from statsmodels>=0.12->arch) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ramon\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.12->arch) (3.0.9)
# Requirement already satisfied: six in c:\users\ramon\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.12->arch) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Modelos GARCH

# %%
from arch import arch_model

# Ajusta el modelo GARCH(1, 1)
garch_model = arch_model(y, vol='Garch', p=1, q=1)
fit_model = garch_model.fit()

# Predicción de la varianza (volatilidad) a 20 años
forecasts = fit_model.forecast(start=0, horizon=20)
future_volatility = forecasts.variance.dropna().iloc[-1]

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), future_volatility, label="Predicciones de Volatilidad a 20 años", linestyle='dashed')
plt.legend()
plt.show()
# Out:
# C:\Users\ramon\anaconda3\lib\site-packages\arch\univariate\base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.004896. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# C:\Users\ramon\anaconda3\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 1285176394.9334831
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 2644879.876453178
# Iteration:      3,   Func. Count:     28,   Neg. LLF: 11697116149324.783
# Iteration:      4,   Func. Count:     37,   Neg. LLF: -89.77570476917748
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -89.77570657209701
#             Iterations: 8
#             Function evaluations: 37
#             Gradient evaluations: 4

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# Crear y entrenar el modelo
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X, y)

# Hacer predicciones a 20 años
predictions = rf_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Crear y entrenar el modelo
gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)
gb_model.fit(X, y)

# Hacer predicciones a 20 años
predictions = gb_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
import xgboost as xgb

# Crear y entrenar el modelo
xgb_model = xgb.XGBRegressor(n_estimators=100)
xgb_model.fit(X, y)

# Hacer predicciones a 20 años
predictions = xgb_model.predict(X_future)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.legend()
plt.show()

# %%
pip install pymc3
# Out:
# Requirement already satisfied: pymc3 in c:\users\ramon\anaconda3\lib\site-packages (3.11.5)
# Requirement already satisfied: numpy<1.22.2,>=1.15.0 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (1.21.5)
# Requirement already satisfied: deprecat in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (2.1.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (1.4.4)
# Requirement already satisfied: dill in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (0.3.4)
# Requirement already satisfied: fastprogress>=0.2.0 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (1.0.3)
# Requirement already satisfied: arviz>=0.11.0 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (0.12.1)
# Requirement already satisfied: theano-pymc==1.1.2 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (1.1.2)
# Requirement already satisfied: cachetools>=4.2.1 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (5.3.1)
# Requirement already satisfied: scipy<1.8.0,>=1.7.3 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (1.7.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (4.3.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (0.5.2)
# Requirement already satisfied: semver>=2.13.0 in c:\users\ramon\anaconda3\lib\site-packages (from pymc3) (3.0.1)
# Requirement already satisfied: filelock in c:\users\ramon\anaconda3\lib\site-packages (from theano-pymc==1.1.2->pymc3) (3.6.0)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\ramon\anaconda3\lib\site-packages (from arviz>=0.11.0->pymc3) (3.5.2)
# Requirement already satisfied: netcdf4 in c:\users\ramon\anaconda3\lib\site-packages (from arviz>=0.11.0->pymc3) (1.6.4)
# Requirement already satisfied: xarray>=0.16.1 in c:\users\ramon\anaconda3\lib\site-packages (from arviz>=0.11.0->pymc3) (2023.7.0)
# Requirement already satisfied: packaging in c:\users\ramon\anaconda3\lib\site-packages (from arviz>=0.11.0->pymc3) (21.3)
# Requirement already satisfied: xarray-einstats>=0.2 in c:\users\ramon\anaconda3\lib\site-packages (from arviz>=0.11.0->pymc3) (0.6.0)
# Requirement already satisfied: setuptools>=38.4 in c:\users\ramon\anaconda3\lib\site-packages (from arviz>=0.11.0->pymc3) (63.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ramon\anaconda3\lib\site-packages (from pandas>=0.24.0->pymc3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramon\anaconda3\lib\site-packages (from pandas>=0.24.0->pymc3) (2022.1)
# Requirement already satisfied: six in c:\users\ramon\anaconda3\lib\site-packages (from patsy>=0.5.1->pymc3) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\ramon\anaconda3\lib\site-packages (from deprecat->pymc3) (1.14.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ramon\anaconda3\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramon\anaconda3\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ramon\anaconda3\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ramon\anaconda3\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramon\anaconda3\lib\site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (0.11.0)
# Requirement already satisfied: certifi in c:\users\ramon\anaconda3\lib\site-packages (from netcdf4->arviz>=0.11.0->pymc3) (2022.9.14)
# Requirement already satisfied: cftime in c:\users\ramon\anaconda3\lib\site-packages (from netcdf4->arviz>=0.11.0->pymc3) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymc3 as pm

# Define el modelo bayesiano
with pm.Model() as bayesian_model:
    alpha = pm.Normal('alpha', mu=0, sd=10)
    beta = pm.Normal('beta', mu=0, sd=10, shape=X.shape[1])
    sigma = pm.HalfNormal('sigma', sd=1)
    y_est = alpha + pm.math.dot(beta, X.T)
    likelihood = pm.Normal('y', mu=y_est, sd=sigma, observed=y)
    
    # Inferencia
    trace = pm.sample(2000)

# Puedes usar la traza para hacer predicciones y analizar las distribuciones posteriores de los parámetros.
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# C:\Users\ramon\anaconda3\lib\site-packages\deprecat\classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# C:\Users\ramon\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: divide by zero encountered in log
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# C:\Users\ramon\anaconda3\lib\site-packages\theano\tensor\elemwise.py:826: RuntimeWarning: invalid value encountered in multiply
#   variables = ufunc(*ufunc_args, **ufunc_kwargs)
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta, alpha]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 03:08&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 202 seconds.
# The acceptance probability does not match the target. It is 0.8877271124190498, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

# Kernel para el GP
kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))

# Crear y entrenar el modelo
gp_model = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10)
gp_model.fit(X, y)

# Hacer predicciones a 20 años
predictions, sigma = gp_model.predict(X_future, return_std=True)

plt.plot(y, label="Datos Actuales")
plt.plot(range(len(y), len(y) + 20), predictions, label="Predicciones a 20 años", linestyle='dashed')
plt.fill_between(range(len(y), len(y) + 20), predictions - sigma, predictions + sigma, alpha=0.2)
plt.legend()
plt.show()
