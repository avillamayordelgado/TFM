# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the file
file_path = "C:/Users/ramon/Documents/MASTER BIG DATA & DATA SCIENCE/TFM/Nueva carpeta/TFM-main/datas/Option_B/Brazil_Energy balance matrix.xlsx"

#File excel with multi-sheet_names is read as an Dictionary
Dict = pd.read_excel(file_path, sheet_name=None, skiprows=range(4), skipfooter=3)

for k in Dict.keys():       
    # Round the values of each column in dataframe with 2 decimals
    Dict[k]=Dict[k].applymap(lambda x: round(x, 2) if isinstance(x, (int, float)) else x)
    
    #Ignor the first row (unit) in each df
    Dict[k]=Dict[k][1:]
    
    #Rename of columns in df
    Dict[k].rename(columns={'Unnamed: 0': 'SECTOR','OTHER PRIMARY_x000d_\n':'OTHER PRIMARY'}, inplace=True)   
    
print(Dict.keys())

# Convert the keys of Dict to only contain the year
for k in list(Dict.keys()):
    k_new = k.split(' - ')[0]
    Dict[k_new] = Dict.pop(k)
    
    Dict[k_new]["Year"]=k_new
        
print('\n')
print(Dict.keys())



#Save the Clean Dictionary in Excel with multi-sheet_names
file_path="C:/Users/ramon/Documents/MASTER BIG DATA & DATA SCIENCE/TFM/Nueva carpeta/TFM-main/datas/Option_B/Brazil_Energy balance matrix_cleaned.xlsx"
with pd.ExcelWriter(file_path) as writer:
    for k, df in Dict.items():
        df.to_excel(writer, sheet_name=k)

df_2021=Dict['2021']
df_2021.tail(27)
# Out:
# dict_keys(['1970 - Brazil', '1971 - Brazil', '1972 - Brazil', '1973 - Brazil', '1974 - Brazil', '1975 - Brazil', '1976 - Brazil', '1977 - Brazil', '1978 - Brazil', '1979 - Brazil', '1980 - Brazil', '1981 - Brazil', '1982 - Brazil', '1983 - Brazil', '1984 - Brazil', '1985 - Brazil', '1986 - Brazil', '1987 - Brazil', '1988 - Brazil', '1989 - Brazil', '1990 - Brazil', '1991 - Brazil', '1992 - Brazil', '1993 - Brazil', '1994 - Brazil', '1995 - Brazil', '1996 - Brazil', '1997 - Brazil', '1998 - Brazil', '1999 - Brazil', '2000 - Brazil', '2001 - Brazil', '2002 - Brazil', '2003 - Brazil', '2004 - Brazil', '2005 - Brazil', '2006 - Brazil', '2007 - Brazil', '2008 - Brazil', '2009 - Brazil', '2010 - Brazil', '2011 - Brazil', '2012 - Brazil', '2013 - Brazil', '2014 - Brazil', '2015 - Brazil', '2016 - Brazil', '2017 - Brazil', '2018 - Brazil', '2019 - Brazil', '2020 - Brazil', '2021 - Brazil'])
#
#
# dict_keys(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'])
#                                         SECTOR        OIL NATURAL GAS  \
# 1                                   PRODUCTION  152713.43    26371.48
# 2                                       IMPORT    7359.21    14796.23
# 3                                       EXPORT   65724.07         NaN
# 4                                 STOCK CHANGE   -1007.78    -3598.93
# 5                                       UNUSED        NaN     1217.87
# 6                                 TOTAL SUPPLY   93340.78    36350.92
# 7                                   REFINERIES  -92551.74         NaN
# 8                                POWER PLANTS         NaN    -13219.0
# 9                               SELF-PRODUCERS        NaN    -4266.04
# 10                                  GAS PLANTS        NaN    -2583.62
# 11                             CHARCOAL PLANTS        NaN         NaN
# 12     COKE PLANTS AND BLAST FURNACES_x000d_\n        NaN         NaN
# 13                                DISTILLERIES        NaN         NaN
# 14                               OTHER CENTERS    -734.46         NaN
# 15                        TOTAL TRANSFORMATION   -93286.2   -20068.66
# 16                             OWN CONSUMPTION        NaN     4706.08
# 17                                      LOSSES        NaN      241.54
# 18                                  ADJUSTMENT      54.58      -55.21
# 19                                  TRANSPORT         NaN      1903.2
# 20                                  INDUSTRIAL        NaN     8417.91
# 21                                 RESIDENTIAL        NaN      454.97
# 22                COMMERCIAL, SERVICES, PUBLIC        NaN      136.77
# 23             AGRICULTURE, FISHING AND MINING        NaN      261.08
# 24                     CONSTRUCTION AND OTHERS        NaN         NaN
# 25                          ENERGY CONSUMPTION        NaN    11173.92
# 26                      NON-ENERGY CONSUMPTION        NaN      215.94
# 27                           FINAL CONSUMPTION        NaN    11389.86
#
#         COAL HYDROENERGY GEOTHERMAL  NUCLEAR  FIREWOOD SUGARCANE AND PRODUCTS  \
# 1    2633.08    31125.01        NaN  3835.75  26017.95               49469.74
# 2   13216.31         NaN        NaN      NaN       NaN                    NaN
# 3        NaN         NaN        NaN      NaN       NaN                    NaN
# 4      67.82         NaN        NaN      NaN       NaN                    NaN
# 5        NaN         NaN        NaN      NaN       NaN                    NaN
# 6   15917.21    31125.01        NaN  3835.75  26017.95               49469.74
# 7        NaN         NaN        NaN      NaN       NaN                    NaN
# 8   -4189.67   -29752.22        NaN -3835.75    -56.11                    NaN
# 9    -215.78    -1372.79        NaN      NaN   -373.38               -5782.78
# 10       NaN         NaN        NaN      NaN       NaN                    NaN
# 11       NaN         NaN        NaN      NaN  -7346.03                    NaN
# 12  -7849.84         NaN        NaN      NaN       NaN                    NaN
# 13       NaN         NaN        NaN      NaN       NaN              -15381.37
# 14       NaN         NaN        NaN      NaN       NaN                    NaN
# 15 -12255.29   -31125.01        NaN -3835.75  -7775.51              -21164.15
# 16       NaN         NaN        NaN      NaN       NaN                12887.1
# 17      17.9         NaN        NaN      NaN       NaN                    NaN
# 18      0.49         0.0        NaN      NaN       NaN                    0.0
# 19       NaN         NaN        NaN      NaN       NaN                    NaN
# 20   3497.42         NaN        NaN      NaN   7588.34                15418.5
# 21       NaN         NaN        NaN      NaN   7422.22                    NaN
# 22       NaN         NaN        NaN      NaN     81.99                    NaN
# 23    146.11         NaN        NaN      NaN    3149.9                    NaN
# 24       NaN         NaN        NaN      NaN       NaN                    NaN
# 25   3643.53         NaN        NaN      NaN  18242.44                15418.5
# 26       NaN         NaN        NaN      NaN       NaN                    NaN
# 27   3643.53         NaN        NaN      NaN  18242.44                15418.5
#
#    OTHER PRIMARY  ... DIESEL OIL  FUEL OIL     COKE CHARCOAL    GASES  \
# 1       28037.32  ...   41972.43  16109.25  6866.86  3915.43  2060.14
# 2            NaN  ...   12211.92    581.74  1150.16      NaN      NaN
# 3            NaN  ...      499.3  11963.08      NaN      NaN      NaN
# 4            NaN  ...     -22.66   -431.71    -92.5      NaN      NaN
# 5            NaN  ...        NaN       NaN      NaN      NaN      NaN
# 6       28037.32  ...   53662.39    4296.2  7924.52  3915.43  2060.14
# 7            NaN  ...   36249.21  16109.25      NaN      NaN      NaN
# 8       -7138.42  ...   -1371.21  -1656.49      NaN      NaN      NaN
# 9       -5688.41  ...    -561.98   -225.32      NaN      NaN  -394.47
# 10           NaN  ...        NaN       NaN      NaN      NaN      NaN
# 11           NaN  ...        NaN       NaN      NaN  3915.43      NaN
# 12           NaN  ...        NaN       NaN  6866.86      NaN  2060.14
# 13       -158.61  ...        NaN       NaN      NaN      NaN      NaN
# 14       -5589.7  ...    5723.21       NaN      NaN      NaN      NaN
# 15     -18575.13  ...   -1933.18  -1881.81      NaN      NaN  -394.47
# 16           NaN  ...     509.02    131.89      NaN      NaN   205.16
# 17           NaN  ...        NaN       NaN     41.3    57.86      NaN
# 18         -0.05  ...     -50.87     -0.43      0.0      0.0   -22.68
# 19           NaN  ...    42980.4    776.88      NaN      NaN      NaN
# 20       8568.38  ...     785.48   1383.83  7850.75  3359.75  1326.98
# 21        716.94  ...        NaN       NaN      NaN   411.72      NaN
# 22        176.91  ...      43.85      23.4      NaN    76.99      NaN
# 23           NaN  ...    7461.33     98.82    32.48     9.11      NaN
# 24           NaN  ...        NaN       NaN      NaN      NaN      NaN
# 25       9462.23  ...   51271.06   2282.93  7883.22  3857.57  1326.98
# 26           NaN  ...        NaN       NaN      NaN      NaN   156.21
# 27       9462.23  ...   51271.06   2282.93  7883.22  3857.57  1483.19
#
#    OTHER SECONDARY NON-ENERGY TOTAL SECUNDARIES      TOTAL  Year
# 1          9109.18    5630.96         189790.51  320203.76  2021
# 2          2901.18    1712.36           31674.9   67046.66  2021
# 3           841.83     385.76          17331.46   83055.53  2021
# 4           -25.31       -8.2            -35.62   -4574.51  2021
# 5              NaN        NaN               NaN    1217.87  2021
# 6         11143.23    6949.36         204098.32   298402.5  2021
# 7           7528.3    4710.47          95389.98    2838.23  2021
# 8            -75.3        NaN           46508.5  -14785.66  2021
# 9           -551.3        NaN           9776.97   -9655.28  2021
# 10             NaN     920.49           2354.08    -229.54  2021
# 11             NaN        NaN           3915.43   -3430.59  2021
# 12        -1280.22        NaN            8927.0    -203.06  2021
# 13             NaN        NaN          15486.71     -53.26  2021
# 14         1580.88    -233.26           7431.85     -991.3  2021
# 15        -1906.82    -233.26          -8215.28  -26510.47  2021
# 16         3078.97        NaN           7258.66   24851.84  2021
# 17             NaN        NaN            9456.1    9715.53  2021
# 18           28.88      89.41            130.32     130.14  2021
# 19             NaN        NaN           83272.9    85176.1  2021
# 20         5931.98        NaN          38899.12   82389.66  2021
# 21             NaN        NaN          19827.62   28421.75  2021
# 22             NaN        NaN          12152.68   12548.34  2021
# 23          196.57        NaN           11864.6   15421.69  2021
# 24             NaN        NaN               NaN        NaN  2021
# 25         6128.55        NaN         166016.93  223957.54  2021
# 26             NaN    6626.69          13021.03   13236.97  2021
# 27         6128.55    6626.69         179037.96  237194.52  2021
#
# [27 rows x 25 columns]

# %%
# Ajustar las opciones de visualización de Pandas para ver todas las columnas
pd.set_option('display.max_columns', None)

df_2021.tail(27)
# Out:
#                                         SECTOR        OIL NATURAL GAS  \
# 1                                   PRODUCTION  152713.43    26371.48
# 2                                       IMPORT    7359.21    14796.23
# 3                                       EXPORT   65724.07         NaN
# 4                                 STOCK CHANGE   -1007.78    -3598.93
# 5                                       UNUSED        NaN     1217.87
# 6                                 TOTAL SUPPLY   93340.78    36350.92
# 7                                   REFINERIES  -92551.74         NaN
# 8                                POWER PLANTS         NaN    -13219.0
# 9                               SELF-PRODUCERS        NaN    -4266.04
# 10                                  GAS PLANTS        NaN    -2583.62
# 11                             CHARCOAL PLANTS        NaN         NaN
# 12     COKE PLANTS AND BLAST FURNACES_x000d_\n        NaN         NaN
# 13                                DISTILLERIES        NaN         NaN
# 14                               OTHER CENTERS    -734.46         NaN
# 15                        TOTAL TRANSFORMATION   -93286.2   -20068.66
# 16                             OWN CONSUMPTION        NaN     4706.08
# 17                                      LOSSES        NaN      241.54
# 18                                  ADJUSTMENT      54.58      -55.21
# 19                                  TRANSPORT         NaN      1903.2
# 20                                  INDUSTRIAL        NaN     8417.91
# 21                                 RESIDENTIAL        NaN      454.97
# 22                COMMERCIAL, SERVICES, PUBLIC        NaN      136.77
# 23             AGRICULTURE, FISHING AND MINING        NaN      261.08
# 24                     CONSTRUCTION AND OTHERS        NaN         NaN
# 25                          ENERGY CONSUMPTION        NaN    11173.92
# 26                      NON-ENERGY CONSUMPTION        NaN      215.94
# 27                           FINAL CONSUMPTION        NaN    11389.86
#
#         COAL HYDROENERGY GEOTHERMAL  NUCLEAR  FIREWOOD SUGARCANE AND PRODUCTS  \
# 1    2633.08    31125.01        NaN  3835.75  26017.95               49469.74
# 2   13216.31         NaN        NaN      NaN       NaN                    NaN
# 3        NaN         NaN        NaN      NaN       NaN                    NaN
# 4      67.82         NaN        NaN      NaN       NaN                    NaN
# 5        NaN         NaN        NaN      NaN       NaN                    NaN
# 6   15917.21    31125.01        NaN  3835.75  26017.95               49469.74
# 7        NaN         NaN        NaN      NaN       NaN                    NaN
# 8   -4189.67   -29752.22        NaN -3835.75    -56.11                    NaN
# 9    -215.78    -1372.79        NaN      NaN   -373.38               -5782.78
# 10       NaN         NaN        NaN      NaN       NaN                    NaN
# 11       NaN         NaN        NaN      NaN  -7346.03                    NaN
# 12  -7849.84         NaN        NaN      NaN       NaN                    NaN
# 13       NaN         NaN        NaN      NaN       NaN              -15381.37
# 14       NaN         NaN        NaN      NaN       NaN                    NaN
# 15 -12255.29   -31125.01        NaN -3835.75  -7775.51              -21164.15
# 16       NaN         NaN        NaN      NaN       NaN                12887.1
# 17      17.9         NaN        NaN      NaN       NaN                    NaN
# 18      0.49         0.0        NaN      NaN       NaN                    0.0
# 19       NaN         NaN        NaN      NaN       NaN                    NaN
# 20   3497.42         NaN        NaN      NaN   7588.34                15418.5
# 21       NaN         NaN        NaN      NaN   7422.22                    NaN
# 22       NaN         NaN        NaN      NaN     81.99                    NaN
# 23    146.11         NaN        NaN      NaN    3149.9                    NaN
# 24       NaN         NaN        NaN      NaN       NaN                    NaN
# 25   3643.53         NaN        NaN      NaN  18242.44                15418.5
# 26       NaN         NaN        NaN      NaN       NaN                    NaN
# 27   3643.53         NaN        NaN      NaN  18242.44                15418.5
#
#    OTHER PRIMARY TOTAL PRIMARIES ELECTRICITY      LPG GASOLINE/ALCOHOL  \
# 1       28037.32       320203.76    56285.46  5856.96         38705.57
# 2            NaN        35371.75      1985.7  2448.38          8383.05
# 3            NaN        65724.07        3.79     0.12          2573.24
# 4            NaN        -4538.89         NaN   -63.68            661.0
# 5            NaN         1217.87         NaN      NaN              NaN
# 6       28037.32       284094.68    58267.37  8241.55         45176.38
# 7            NaN       -92551.74         NaN  4410.84         23103.65
# 8       -7138.42       -58191.16     46508.5      NaN              NaN
# 9       -5688.41       -17699.18     9776.97      NaN              NaN
# 10           NaN        -2583.62         NaN  1318.38           115.21
# 11           NaN        -7346.03         NaN      NaN              NaN
# 12           NaN        -7849.84         NaN      NaN              NaN
# 13       -158.61       -15539.97         NaN      NaN         15486.71
# 14       -5589.7        -6324.16         NaN   127.75         -1865.73
# 15     -18575.13       -208085.7         NaN      NaN         -1865.73
# 16           NaN        17593.18     3333.63      NaN              NaN
# 17           NaN          259.43     9299.56      NaN            57.38
# 18         -0.05           -0.19         0.0   -35.48           123.53
# 19           NaN          1903.2      171.57      NaN          36884.7
# 20       8568.38        43490.54    17209.25  1050.97              NaN
# 21        716.94         8594.13    12908.61  6505.67              NaN
# 22        176.91          395.66    11346.64    661.8              NaN
# 23           NaN         3557.08      3998.1     58.6             8.77
# 24           NaN             NaN         NaN      NaN              NaN
# 25       9462.23        57940.62    45634.17  8277.03         36893.47
# 26           NaN          215.94         NaN      NaN          6236.28
# 27       9462.23        58156.56    45634.17  8277.03         43129.75
#
#    KEROSENE/JET FUEL DIESEL OIL  FUEL OIL     COKE CHARCOAL    GASES  \
# 1            3278.26   41972.43  16109.25  6866.86  3915.43  2060.14
# 2             300.41   12211.92    581.74  1150.16      NaN      NaN
# 3            1064.33      499.3  11963.08      NaN      NaN      NaN
# 4             -52.57     -22.66   -431.71    -92.5      NaN      NaN
# 5                NaN        NaN       NaN      NaN      NaN      NaN
# 6            2461.76   53662.39    4296.2  7924.52  3915.43  2060.14
# 7            3278.26   36249.21  16109.25      NaN      NaN      NaN
# 8                NaN   -1371.21  -1656.49      NaN      NaN      NaN
# 9                NaN    -561.98   -225.32      NaN      NaN  -394.47
# 10               NaN        NaN       NaN      NaN      NaN      NaN
# 11               NaN        NaN       NaN      NaN  3915.43      NaN
# 12               NaN        NaN       NaN  6866.86      NaN  2060.14
# 13               NaN        NaN       NaN      NaN      NaN      NaN
# 14               NaN    5723.21       NaN      NaN      NaN      NaN
# 15               NaN   -1933.18  -1881.81      NaN      NaN  -394.47
# 16               NaN     509.02    131.89      NaN      NaN   205.16
# 17               NaN        NaN       NaN     41.3    57.86      NaN
# 18             -2.04     -50.87     -0.43      0.0      0.0   -22.68
# 19           2459.35    42980.4    776.88      NaN      NaN      NaN
# 20              0.14     785.48   1383.83  7850.75  3359.75  1326.98
# 21              1.63        NaN       NaN      NaN   411.72      NaN
# 22               NaN      43.85      23.4      NaN    76.99      NaN
# 23              0.84    7461.33     98.82    32.48     9.11      NaN
# 24               NaN        NaN       NaN      NaN      NaN      NaN
# 25           2461.95   51271.06   2282.93  7883.22  3857.57  1326.98
# 26              1.85        NaN       NaN      NaN      NaN   156.21
# 27            2463.8   51271.06   2282.93  7883.22  3857.57  1483.19
#
#    OTHER SECONDARY NON-ENERGY TOTAL SECUNDARIES      TOTAL  Year
# 1          9109.18    5630.96         189790.51  320203.76  2021
# 2          2901.18    1712.36           31674.9   67046.66  2021
# 3           841.83     385.76          17331.46   83055.53  2021
# 4           -25.31       -8.2            -35.62   -4574.51  2021
# 5              NaN        NaN               NaN    1217.87  2021
# 6         11143.23    6949.36         204098.32   298402.5  2021
# 7           7528.3    4710.47          95389.98    2838.23  2021
# 8            -75.3        NaN           46508.5  -14785.66  2021
# 9           -551.3        NaN           9776.97   -9655.28  2021
# 10             NaN     920.49           2354.08    -229.54  2021
# 11             NaN        NaN           3915.43   -3430.59  2021
# 12        -1280.22        NaN            8927.0    -203.06  2021
# 13             NaN        NaN          15486.71     -53.26  2021
# 14         1580.88    -233.26           7431.85     -991.3  2021
# 15        -1906.82    -233.26          -8215.28  -26510.47  2021
# 16         3078.97        NaN           7258.66   24851.84  2021
# 17             NaN        NaN            9456.1    9715.53  2021
# 18           28.88      89.41            130.32     130.14  2021
# 19             NaN        NaN           83272.9    85176.1  2021
# 20         5931.98        NaN          38899.12   82389.66  2021
# 21             NaN        NaN          19827.62   28421.75  2021
# 22             NaN        NaN          12152.68   12548.34  2021
# 23          196.57        NaN           11864.6   15421.69  2021
# 24             NaN        NaN               NaN        NaN  2021
# 25         6128.55        NaN         166016.93  223957.54  2021
# 26             NaN    6626.69          13021.03   13236.97  2021
# 27         6128.55    6626.69         179037.96  237194.52  2021

# %%
Dict2=Dict.copy()

for k in Dict2.keys():
   # selected_columns = ['SECTOR', 'OIL', 'NATURAL GAS', 'COAL', 'HYDROENERGY', 'GEOTHERMAL',
    #   'NUCLEAR', 'FIREWOOD', 'SUGARCANE AND PRODUCTS', 'OTHER PRIMARY', 'TOTAL PRIMARIES','Year']
    selected_columns = ['SECTOR','TOTAL','Year']
    Dict2[k]=Dict2[k][selected_columns]
    selected_rows=['   INDUSTRIAL']
    Dict2[k]=Dict2[k][Dict2[k]['SECTOR'].isin(selected_rows)]
    
    # Concatenate all DataFrames in Dict vertically
    df_conc = pd.concat(Dict2.values(), ignore_index=True)
    
    # Move the column "Year" to the first position
    last_column_name = df_conc.columns[-1]
    # Reorder the columns by concatenating the last column with the rest of the DataFrame
    df_conc = pd.concat([df_conc[last_column_name], df_conc.drop(columns=last_column_name)], axis=1) # Datafames of TOTAL SUPPLY
    df_conc.set_index("Year", inplace=True)
    df_conc.index = df_conc.index.astype(int)
    #df_TC1=df_conc.drop(columns="SECTOR")
    # Set the value "NaN" by Zero
    df_TC1 = df_conc.apply(lambda column: column.fillna(0))
    

df_TC1
# Out:
#              SECTOR     TOTAL
# Year
# 1970     INDUSTRIAL  16020.92
# 1971     INDUSTRIAL  17454.73
# 1972     INDUSTRIAL  19026.99
# 1973     INDUSTRIAL  21493.43
# 1974     INDUSTRIAL  23257.01
# 1975     INDUSTRIAL  24242.81
# 1976     INDUSTRIAL  26878.32
# 1977     INDUSTRIAL  29064.72
# 1978     INDUSTRIAL  30382.47
# 1979     INDUSTRIAL  32292.48
# 1980     INDUSTRIAL  34333.91
# 1981     INDUSTRIAL  31540.07
# 1982     INDUSTRIAL  32059.56
# 1983     INDUSTRIAL  32334.18
# 1984     INDUSTRIAL  34525.65
# 1985     INDUSTRIAL  36011.72
# 1986     INDUSTRIAL  38527.42
# 1987     INDUSTRIAL  40235.05
# 1988     INDUSTRIAL  40606.77
# 1989     INDUSTRIAL  40627.06
# 1990     INDUSTRIAL  40150.91
# 1991     INDUSTRIAL  40099.55
# 1992     INDUSTRIAL  40706.84
# 1993     INDUSTRIAL  42626.62
# 1994     INDUSTRIAL  45312.79
# 1995     INDUSTRIAL  46328.21
# 1996     INDUSTRIAL  48631.15
# 1997     INDUSTRIAL  49712.87
# 1998     INDUSTRIAL  51440.28
# 1999     INDUSTRIAL  56086.30
# 2000     INDUSTRIAL  56964.80
# 2001     INDUSTRIAL  57390.46
# 2002     INDUSTRIAL  65641.02
# 2003     INDUSTRIAL  68395.56
# 2004     INDUSTRIAL  69590.36
# 2005     INDUSTRIAL  70266.36
# 2006     INDUSTRIAL  73324.16
# 2007     INDUSTRIAL  78418.45
# 2008     INDUSTRIAL  78879.36
# 2009     INDUSTRIAL  74338.79
# 2010     INDUSTRIAL  82179.55
# 2011     INDUSTRIAL  85265.02
# 2012     INDUSTRIAL  85362.25
# 2013     INDUSTRIAL  84952.58
# 2014     INDUSTRIAL  83781.40
# 2015     INDUSTRIAL  81213.58
# 2016     INDUSTRIAL  80812.34
# 2017     INDUSTRIAL  82334.45
# 2018     INDUSTRIAL  78167.81
# 2019     INDUSTRIAL  76310.71
# 2020     INDUSTRIAL  79593.61
# 2021     INDUSTRIAL  82389.66

# %%
# Group by Year and SECTOR, and sum the TOTAL values
grouped_df = df_TC1.groupby(['Year', 'SECTOR'])['TOTAL'].sum().reset_index()

# Pivot the data
pivot_df = grouped_df.pivot(index='Year', columns='SECTOR', values='TOTAL')

# Display the result
pivot_df.head(-1)
# Out:
# SECTOR     INDUSTRIAL
# Year
# 1970         16020.92
# 1971         17454.73
# 1972         19026.99
# 1973         21493.43
# 1974         23257.01
# 1975         24242.81
# 1976         26878.32
# 1977         29064.72
# 1978         30382.47
# 1979         32292.48
# 1980         34333.91
# 1981         31540.07
# 1982         32059.56
# 1983         32334.18
# 1984         34525.65
# 1985         36011.72
# 1986         38527.42
# 1987         40235.05
# 1988         40606.77
# 1989         40627.06
# 1990         40150.91
# 1991         40099.55
# 1992         40706.84
# 1993         42626.62
# 1994         45312.79
# 1995         46328.21
# 1996         48631.15
# 1997         49712.87
# 1998         51440.28
# 1999         56086.30
# 2000         56964.80
# 2001         57390.46
# 2002         65641.02
# 2003         68395.56
# 2004         69590.36
# 2005         70266.36
# 2006         73324.16
# 2007         78418.45
# 2008         78879.36
# 2009         74338.79
# 2010         82179.55
# 2011         85265.02
# 2012         85362.25
# 2013         84952.58
# 2014         83781.40
# 2015         81213.58
# 2016         80812.34
# 2017         82334.45
# 2018         78167.81
# 2019         76310.71
# 2020         79593.61

# %%
media = pivot_df['   INDUSTRIAL'].mean()
desviacion_tipica = pivot_df['   INDUSTRIAL'].std()
moda = pivot_df['   INDUSTRIAL'].mode().iloc[0] # La moda puede tener más de un valor, así que tomamos el primero
mediana = pivot_df['   INDUSTRIAL'].median()

print("La media de INDUSTRIAL es:", media)
print("La desviación típica de INDUSTRIAL es:", desviacion_tipica)
print("La moda de INDUSTRIAL es:", moda)
print("La mediana de INDUSTRIAL es:", mediana)
# Out:
# La media de INDUSTRIAL es: 52645.828269230784
# La desviación típica de INDUSTRIAL es: 22436.478275292695
# La moda de INDUSTRIAL es: 16020.92
# La mediana de INDUSTRIAL es: 47479.68

# %%
# Leer el archivo de Excel
data = pd.read_excel("C:/Users/ramon/Documents/MASTER BIG DATA & DATA SCIENCE/TFM/Nueva carpeta/TFM-main/datas/VariablesExogenas_Brasil.xlsx")

# Mostrar las primeras filas del DataFrame para entender su contenido
data.head()
# Out:
#    YEAR           GDP  GDP GROWTH  GDP per capita  INFLATION  \
# 0  1969  3.717164e+10    9.500000      395.441385  20.051784
# 1  1970  4.232766e+10   10.400000      439.220916  16.255112
# 2  1971  4.886983e+10   11.342922      494.802750  19.384585
# 3  1972  5.843486e+10   11.940348      577.451537  19.867092
# 4  1973  8.359228e+10   13.968722      806.354513  29.580357
#
#    UNEMPLOYMENT RATE  EXCHANGE RATE  INTEREST RATE  PRICE INDEX  \
# 0                0.0   1.763363e-12            0.0          0.0
# 1                0.0   1.987854e-12            0.0          0.0
# 2                0.0   2.288221e-12            0.0          0.0
# 3                0.0   2.567960e-12            0.0          0.0
# 4                0.0   2.650941e-12            0.0          0.0
#
#    HOUSEHOLD FINAL CONSUMPTION EXPENDITURE  POPULATION  POPULATION DENSITY  \
# 0                                -4.195743    94000381           11.246567
# 1                                18.359484    96369875           11.530062
# 2                                12.979300    98766288           11.816778
# 3                                11.532541   101194394           12.107286
# 4                                 9.150809   103666904           12.403107
#
#    POPULATION GROWTH  POPULATION  BETWEEN 0-14 YEARS  \
# 0           2.522098                       43.012849
# 1           2.489482                       42.652129
# 2           2.456268                       42.269910
# 3           2.428703                       41.866369
# 4           2.413955                       41.444081
#
#    POPULATION  BETWEEN15-64 YEARS  POPULATION +65 YEARS  URBAN POPULATION  \
# 0                       53.864518              3.122633            54.940
# 1                       54.165355              3.182516            55.909
# 2                       54.488154              3.241935            56.894
# 3                       54.831959              3.301672            57.879
# 4                       55.193304              3.362615            58.855
#
#    URBAN POPULATION GROWTH  ACTIVE POPULATION
# 0                 4.303432                  0
# 1                 4.237850                  0
# 2                 4.202721                  0
# 3                 4.145176                  0
# 4                 4.086172                  0

# %%
# Leer el archivo de Excel 'VariablesExogenas_Brasil.xlsx'
data_exogenas = pd.read_excel("C:/Users/ramon/Documents/MASTER BIG DATA & DATA SCIENCE/TFM/Nueva carpeta/TFM-main/datas/VariablesExogenas_Brasil.xlsx")

# Fusionar 'pivot_df' con 'data_exogenas' usando la columna 'YEAR'/'Year'
merged_data = pd.merge(pivot_df, data_exogenas, left_index=True, right_on="YEAR", how="left")

# Mostrar las primeras filas del DataFrame fusionado
merged_data.head(52)
# Out:
#        INDUSTRIAL  YEAR           GDP  GDP GROWTH  GDP per capita  \
# 1        16020.92  1970  4.232766e+10   10.400000      439.220916
# 2        17454.73  1971  4.886983e+10   11.342922      494.802750
# 3        19026.99  1972  5.843486e+10   11.940348      577.451537
# 4        21493.43  1973  8.359228e+10   13.968722      806.354513
# 5        23257.01  1974  1.097945e+11    8.153939     1034.164430
# 6        24242.81  1975  1.292036e+11    5.166649     1188.619532
# 7        26878.32  1976  1.531689e+11   10.257130     1376.347928
# 8        29064.72  1977  1.763441e+11    4.934328     1547.694206
# 9        30382.47  1978  2.002786e+11    4.969898     1716.707728
# 10       32292.48  1979  2.213382e+11    6.759560     1853.019691
# 11       34333.91  1980  2.373935e+11    9.200000     1941.259538
# 12       31540.07  1981  2.580152e+11   -4.250000     2061.349954
# 13       32059.56  1982  2.713141e+11    0.830000     2118.564108
# 14       32334.18  1983  1.896565e+11   -2.930000     1448.009731
# 15       34525.65  1984  1.883400e+11    5.400000     1406.689800
# 16       36011.72  1985  2.108798e+11    7.850000     1541.708890
# 17       38527.42  1986  2.564809e+11    7.490000     1836.684978
# 18       40235.05  1987  2.830568e+11    3.530000     1986.834138
# 19       40606.77  1988  3.078819e+11   -0.060000     2119.611081
# 20       40627.06  1989  4.129908e+11    3.160000     2790.414204
# 21       40150.91  1990  4.649891e+11   -4.350000     3085.396216
# 22       40099.55  1991  4.077291e+11    1.032190     2659.048558
# 23       40706.84  1992  3.905666e+11   -0.544072     2505.225033
# 24       42626.62  1993  4.382995e+11    4.924690     2766.328477
# 25       45312.79  1994  5.462297e+11    5.852870     3393.142926
# 26       46328.21  1995  7.693333e+11    4.223794     4704.961546
# 27       48631.15  1996  8.504264e+11    2.208864     5121.905407
# 28       49712.87  1997  8.832065e+11    3.394846     5240.128796
# 29       51440.28  1998  8.637110e+11    0.338098     5049.766120
# 9                        57.116595              3.680715            63.625
# 10                       57.468959              3.739888            64.551
# 11                       57.786066              3.796354            65.468
# 12                       58.063044              3.849548            66.370
# 13                       58.303049              3.900909            67.262
# 14                       58.515373              3.952293            68.142
# 15                       58.718922              4.005911            69.010
# 16                       58.933915              4.063473            69.862
# 17                       59.166655              4.127462            70.703
# 18                       59.415263              4.200463            71.529
# 19                       59.687014              4.282778            72.342
# 20                       59.978607              4.372782            73.139
# 21                       60.294984              4.465553            73.922
# 22                       60.646070              4.560081            74.690
# 23                       61.031972              4.659885            75.444
# 24                       61.446228              4.764052            76.181
# 25                       61.879954              4.869820            76.903
# 26                       62.329565              4.974558            77.610
# 27                       62.791839              5.079584            78.302
# 28                       63.262599              5.186437            79.048
# 29                       63.731802              5.293121            79.781
# 30                       64.198307              5.398945            80.496
# 31                       64.662202              5.503783            81.192
# 32                       65.111514              5.614174            81.553
# 33                       65.546986              5.732844            81.880
# 34                       65.971989              5.858650            82.203
# 35                       66.369637              5.993093            82.521
# 36                       66.729767              6.135684            82.834
# 37                       67.064442              6.284779            83.143
# 38                       67.384151              6.437491            83.448
# 39                       67.700955              6.592997            83.749
# 40                       68.019108              6.750328            84.044
# 41                       68.337353              6.907884            84.335
# 42                       68.650513              7.067247            84.631
# 43                       68.948847              7.237876            84.923
# 44                       69.225961              7.430980            85.209
# 45                       69.444466              7.657443            85.492
# 46                       69.596009              7.906244            85.770
# 47                       69.726550              8.161851            86.042
# 48                       69.824097              8.428128            86.309
# 49                       69.854580              8.705595            86.569
# 50                       69.859464              8.995409            86.824
# 51                       69.874474              9.290755            87.073
# 52                       69.878268              9.581065            87.317
#
#     URBAN POPULATION GROWTH  ACTIVE POPULATION
# 1                  4.237850                  0
# 2                  4.202721                  0
# 3                  4.145176                  0
# 4                  4.086172                  0
# 5                  4.019748                  0
# 6                  3.954820                  0
# 7                  3.911561                  0
# 8                  3.873599                  0
# 9                  3.845077                  0
# 10                 3.802315                  0
# 11                 3.761262                  0
# 12                 3.695893                  0
# 13                 3.623167                  0
# 14                 3.548419                  0
# 15                 3.464253                  0
# 16                 3.365807                  0
# 17                 3.266080                  0
# 18                 3.162848                  0
# 19                 3.068043                  0
# 20                 2.970844                  0
# 21                 2.874730           62129127
# 22                 2.763635           63620325
# 23                 2.662979           65276714
# 24                 2.588308           66978150
# 25                 2.533437           68722270
# 26                 2.477507           70502971
# 27                 2.418151           70221615
# 28                 2.448363           72951024
# 29                 2.391351           74794611
# 30                 2.312434           77242077
# 31                 2.227694           79347235
# 32                 1.764334           81451849
# 33                 1.663006           84252471
# 34                 1.579373           85732532
# 35                 1.525494           88065748
# 36                 1.495783           90599379
# 37                 1.449695           91731711
# 38                 1.398194           92730992
# 39                 1.347339           93935308
# 40                 1.304772           95703669
# 41                 1.285067           95367508
# 42                 1.278957           94948394
# 43                 1.244777           97188186
# 44                 1.204556           98532617
# 45                 1.189409           99628945
# 46                 1.170641          101299233
# 47                 1.127882          102278733
# 48                 1.102097          104079618
# 49                 1.094558          105437485
# 50                 1.060238          107415119
# 51                 0.951553          100641930
# 52                 0.808423          105434083

# %%
# Verificar valores faltantes
missing_values = merged_data.isnull().sum()
print("Valores faltantes por columna:")
print(missing_values)
# Out:
# Valores faltantes por columna:
#    INDUSTRIAL                              0
# YEAR                                       0
# GDP                                        0
# GDP GROWTH                                 0
# GDP per capita                             0
# INFLATION                                  0
# UNEMPLOYMENT RATE                          0
# EXCHANGE RATE                              0
# INTEREST RATE                              0
# PRICE INDEX                                0
# HOUSEHOLD FINAL CONSUMPTION EXPENDITURE    0
# POPULATION                                 0
# POPULATION DENSITY                         0
# POPULATION GROWTH                          0
# POPULATION  BETWEEN 0-14 YEARS             0
# POPULATION  BETWEEN15-64 YEARS             0
# POPULATION +65 YEARS                       0
# URBAN POPULATION                           0
# URBAN POPULATION GROWTH                    0
# ACTIVE POPULATION                          0
# dtype: int64

# %%
# Verificar si los datos son numéricos
non_numeric_columns = merged_data.select_dtypes(exclude=[np.number]).columns
print("Columnas no numéricas:")
print(non_numeric_columns)
# Out:
# Columnas no numéricas:
# Index([], dtype='object')

# %%
columns_to_drop = ['HOUSEHOLD FINAL CONSUMPTION EXPENDITURE','POPULATION  BETWEEN 0-14 YEARS','POPULATION  BETWEEN15-64 YEARS','POPULATION +65 YEARS']

merged_data.drop(columns=columns_to_drop, inplace=True)

# Verificar el DataFrame después de eliminar las columnas
print(merged_data.head())
# Out:
#       INDUSTRIAL  YEAR           GDP  GDP GROWTH  GDP per capita  INFLATION  \
# 1       16020.92  1970  4.232766e+10   10.400000      439.220916  16.255112
# 2       17454.73  1971  4.886983e+10   11.342922      494.802750  19.384585
# 3       19026.99  1972  5.843486e+10   11.940348      577.451537  19.867092
# 4       21493.43  1973  8.359228e+10   13.968722      806.354513  29.580357
# 5       23257.01  1974  1.097945e+11    8.153939     1034.164430  34.605855
#
#    UNEMPLOYMENT RATE  EXCHANGE RATE  INTEREST RATE  PRICE INDEX  POPULATION  \
# 1                0.0   1.987854e-12            0.0          0.0    96369875
# 2                0.0   2.288221e-12            0.0          0.0    98766288
# 3                0.0   2.567960e-12            0.0          0.0   101194394
# 4                0.0   2.650941e-12            0.0          0.0   103666904
# 5                0.0   2.938361e-12            0.0          0.0   106167372
#
#    POPULATION DENSITY  POPULATION GROWTH  URBAN POPULATION  \
# 1           11.530062           2.489482            55.909
# 2           11.816778           2.456268            56.894
# 3           12.107286           2.428703            57.879
# 4           12.403107           2.413955            58.855
# 5           12.702273           2.383392            59.826
#
#    URBAN POPULATION GROWTH  ACTIVE POPULATION
# 1                 4.237850                  0
# 2                 4.202721                  0
# 3                 4.145176                  0
# 4                 4.086172                  0
# 5                 4.019748                  0

# %%
# Imprimir los nombres de las columnas del DataFrame
print(merged_data.columns)
# Out:
# Index(['   INDUSTRIAL', 'YEAR', 'GDP', 'GDP GROWTH', 'GDP per capita',
#        'INFLATION', 'UNEMPLOYMENT RATE', 'EXCHANGE RATE', 'INTEREST RATE',
#        'PRICE INDEX', 'POPULATION', 'POPULATION DENSITY', 'POPULATION GROWTH',
#        'URBAN POPULATION', 'URBAN POPULATION GROWTH', 'ACTIVE POPULATION'],
#       dtype='object')

# %%
correlation_matrix = merged_data.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(merged_data)
scaled_df = pd.DataFrame(scaled_data, columns=merged_data.columns)
scaled_df.set_index(merged_data.index, inplace=True)

# %%
scaled_df.head()
# Out:
#       INDUSTRIAL      YEAR       GDP  GDP GROWTH  GDP per capita  INFLATION  \
# 1       0.000000  0.000000  0.000000    0.805187        0.000000   0.004604
# 2       0.020678  0.019608  0.002542    0.856660        0.004355   0.005749
# 3       0.043352  0.039216  0.006258    0.889273        0.010832   0.005925
# 4       0.078921  0.058824  0.016032    1.000000        0.028769   0.009479
# 5       0.104355  0.078431  0.026213    0.682577        0.046621   0.011318
#
#    UNEMPLOYMENT RATE  EXCHANGE RATE  INTEREST RATE  PRICE INDEX  POPULATION  \
# 1                0.0   0.000000e+00            0.0          0.0    0.000000
# 2                0.0   5.568127e-14            0.0          0.0    0.020316
# 3                0.0   1.075386e-13            0.0          0.0    0.040901
# 4                0.0   1.229213e-13            0.0          0.0    0.061862
# 5                0.0   1.762026e-13            0.0          0.0    0.083060
#
#    POPULATION DENSITY  POPULATION GROWTH  URBAN POPULATION  \
# 1            0.000000           1.000000          0.000000
# 2            0.020204           0.983062          0.031361
# 3            0.040675           0.969004          0.062723
# 4            0.061521           0.961484          0.093798
# 5            0.082602           0.945897          0.124713
#
#    URBAN POPULATION GROWTH  ACTIVE POPULATION
# 1                 1.000000                0.0
# 2                 0.989756                0.0
# 3                 0.972977                0.0
# 4                 0.955771                0.0
# 5                 0.936403                0.0

# %%
SECTORS=['   INDUSTRIAL']

# %%
FEATURES=['YEAR', 'GDP', 'GDP GROWTH', 'GDP per capita',
       'INFLATION', 'UNEMPLOYMENT RATE', 'EXCHANGE RATE', 'INTEREST RATE',
       'PRICE INDEX', 'POPULATION', 'POPULATION DENSITY', 'POPULATION GROWTH',
       'URBAN POPULATION', 'URBAN POPULATION GROWTH', 'ACTIVE POPULATION']

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\ramon\anaconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.57.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.21.12)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: packaging in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (21.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Requirement already satisfied: setuptools in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (63.4.1)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ramon\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ramon\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ramon\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ramon\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\ramon\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ramon\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ramon\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ramon\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.13.0->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ramon\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ramon\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in c:\users\ramon\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ramon\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ramon\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramon\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramon\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ramon\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ramon\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ramon\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\ramon\anaconda3\lib\site-packages (2.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, r2_score
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Conv1D, MaxPooling1D, Flatten


# Assuming you have a DataFrame named df with a target column
target='   INDUSTRIAL'


# Split data into train and test sets 
train_size = int(len(merged_data) * 0.80)
# data without scaling
#train, test = merged_df.iloc[:train_size], merged_df.iloc[train_size:]

#data scaling:
train, test = scaled_df.iloc[:train_size], scaled_df.iloc[train_size:]


#X_train = train[FEATURES].values.reshape((-1, len(FEATURES), 1))
#X_test = test[FEATURES].values.reshape((-1, len(FEATURES), 1))

X_train = train[FEATURES]
X_test = test[FEATURES]
y_train=train[target]   
y_test=test[target]

combined_index = np.concatenate((train.index.values, test.index.values), axis=0)
combined_index
train
# Out:
#        INDUSTRIAL      YEAR       GDP  GDP GROWTH  GDP per capita  INFLATION  \
# 1        0.000000  0.000000  0.000000    0.805187        0.000000   0.004604
# 2        0.020678  0.019608  0.002542    0.856660        0.004355   0.005749
# 3        0.043352  0.039216  0.006258    0.889273        0.010832   0.005925
# 4        0.078921  0.058824  0.016032    1.000000        0.028769   0.009479
# 5        0.104355  0.078431  0.026213    0.682577        0.046621   0.011318
# 6        0.118571  0.098039  0.033754    0.519504        0.058724   0.011070
# 7        0.156579  0.117647  0.043065    0.797388        0.073435   0.013731
# 8        0.188110  0.137255  0.052069    0.506822        0.086862   0.015266
# 9        0.207114  0.156863  0.061368    0.508764        0.100106   0.012643
# 10       0.234659  0.176471  0.069550    0.606459        0.110788   0.018547
# 11       0.264099  0.196078  0.075788    0.739680        0.117702   0.032368
# 12       0.223808  0.215686  0.083800    0.005459        0.127113   0.035436
# 13       0.231300  0.235294  0.088967    0.282771        0.131596   0.035621
# 14       0.235260  0.254902  0.057241    0.077516        0.079050   0.046761
# 15       0.266864  0.274510  0.056730    0.532242        0.075813   0.072465
# 16       0.288296  0.294118  0.065487    0.665985        0.086393   0.089589
# 17       0.324576  0.313725  0.083204    0.646333        0.109508   0.053235
# 18       0.349202  0.333333  0.093530    0.430161        0.121274   0.074100
# 19       0.354563  0.352941  0.103175    0.234187        0.131678   0.228398
# 20       0.354855  0.372549  0.144012    0.409963        0.184243   0.475891
# 21       0.347989  0.392157  0.164215    0.000000        0.207359   1.000000
# 22       0.347248  0.411765  0.141968    0.293808        0.173949   0.151102
# 23       0.356006  0.431373  0.135300    0.207762        0.161896   0.353178
# 24       0.383692  0.450980  0.153845    0.506296        0.182356   0.728965
# 25       0.422430  0.470588  0.195779    0.556964        0.231474   0.818241
# 26       0.437074  0.490196  0.282461    0.468034        0.334271   0.033039
# 27       0.470286  0.509804  0.313968    0.358042        0.366943   0.005409
# 28       0.485886  0.529412  0.326703    0.422783        0.376207   0.001485
# 29       0.510797  0.549020  0.319129    0.255918        0.361290   0.000458
# 30       0.577799  0.568627  0.216531    0.263006        0.236433   0.001588
# 31       0.590469  0.588235  0.238213    0.476996        0.257621   0.000708
# 32       0.596607  0.607843  0.201123    0.313335        0.211813   0.001666
# 33       0.715592  0.627451  0.181623    0.404147        0.186931   0.002242
# 27                 0.469387           0.653741
# 28                 0.478197           0.679150
# 29                 0.461572           0.696314
# 30                 0.438560           0.719099
# 31                 0.413851           0.738697
# 32                 0.278738           0.758290
# 33                 0.249191           0.784363
# 34                 0.224804           0.798142
# 35                 0.209094           0.819864
# 36                 0.200430           0.843451
# 37                 0.186991           0.853993
# 38                 0.171974           0.863296
# 39                 0.157145           0.874507
# 40                 0.144732           0.890970
# 41                 0.138986           0.887841

# %%
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

def Execute_model(model_name,test,train, X_train, X_test, y_train, y_test, FEATURES, target):
    if model_name in ["ARIMA","SARIMA", "ETS"]:
        # Initialize the model with appropriate parameters
        if model_name == "ARIMA":
            model = ARIMA(endog=y_train, order=(5, 1, 0))
        
        if model_name == "SARIMA":
            model = SARIMAX(endog=y_train, order=(5, 1, 0), seasonal_order=(1, 1, 1, 12))
        elif model_name == "ETS":
            model = ExponentialSmoothing(endog=y_train, seasonal='add', seasonal_periods=12)
            
        # Fit the model
        fit_model = model.fit()
        y_pred = fit_model.predict(start=len(y_train), end=len(y_train) + len(y_test) - 1)

    if model_name in ["LSTM", "GRU", "TENSORFLOW"]:
        # Create and compile the deep learning models
        model = Sequential()

        if model_name == "LSTM":
            model.add(LSTM(50, input_shape=(len(FEATURES), 1)))
            model.add(Dense(1))
        elif model_name == "GRU":
            model.add(GRU(50, input_shape=(len(FEATURES), 1)))
            model.add(Dense(1))
        elif model_name == "TENSORFLOW":
            model.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
            model.add(Dropout(0.5))  # Agregar dropout para evitar overfitting
            model.add(Dense(64, activation='relu'))
            model.add(Dense(1, activation='linear'))
        #elif model_name == "CNN":
         #   model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(len(FEATURES), 1)))
          #  model.add(MaxPooling1D(pool_size=2))
           # model.add(Flatten())

        
        model.compile(optimizer='adam', loss='mse')

        # Convert data types to float64
        X_train = X_train.values.astype('float64')
        X_test = X_test.values.astype('float64')

        # Reshape input data for deep learning models
        X_train = X_train.reshape((-1, len(FEATURES), 1))
        X_test = X_test.reshape((-1, len(FEATURES), 1))

        # Ensure y_train and y_test are float64
        y_train = y_train.astype('float64')
        y_test = y_test.astype('float64')

        # Fit the model
        model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=0)

        # Make predictions
        y_pred = model.predict(X_test).flatten()

    # Calculate mean squared error
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    # Calculate R-squared (Coefficient of Determination)
    r2 = r2_score(y_test, y_pred)
    # Define the Plot function within Execute_model
    def Plot(train=train, test=test,X_test=X_test, y_test=y_test, y_pred=y_pred):
        combined_index = np.concatenate((train.index, test.index), axis=0)
        combined_y_pred = np.concatenate((y_train, y_pred), axis=0)
        combined_y_test = np.concatenate((y_train, y_test), axis=0)
        

        plt.figure(figsize=(10, 6))
        
        plt.plot(combined_index, combined_y_pred, label='Predicted')
        plt.plot(combined_index, combined_y_test, label='Actual')
        plt.title(f'Actual and Predicted data of model {model_name} with rmse={rmse:.2f}, R-squared={r2:.2f}')
        plt.xlabel("Year")
        plt.ylabel(target)
        plt.legend()
        plt.grid(True)
        plt.show()
 
    # Call the Plot function
    #Plot(X_test, y_test, y_pred)

  
    results={"model_name":model_name, "rmse":rmse, "y_pred":y_pred, "R-squared": r2, "Plot": Plot()}
    
    return results

# %%
columns=["SECTOR", "model_name", "RMSE"]
df_BEST_MODELS=pd.DataFrame(columns= columns)
for target in SECTORS: 
    
    # Split data into train and test sets 
    train_size = int(len(scaled_df) * 0.80)
    train, test = scaled_df.iloc[:train_size], scaled_df.iloc[train_size:]  
    X_train = train[FEATURES]
    X_test = test[FEATURES]
    y_train = train[target]   
    y_test = test[target]
    
    models=["ARIMA","SARIMA", "ETS","LSTM", "GRU","TENSORFLOW"]
    results=[]
    for model_name in models:
        res=Execute_model(model_name=model_name,test=test,train=train, X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test, FEATURES=FEATURES, target=target)
    
        results.append(res)
    
    #best_accuracy=max(result['Accuracy'] for result in results)
    min_rmse = min(result['rmse'] for result in results)
    best_model = next(result['model_name'] for result in results if result['rmse'] == min_rmse)   
    result_dict = {'SECTOR': target, 'model_name': best_model, 'RMSE': f"{min_rmse:.2f}"}
    df_BEST_MODELS = pd.concat([df_BEST_MODELS, pd.DataFrame([result_dict])], ignore_index=True)
# Out:
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
df_BEST_MODELS
# Out:
#           SECTOR model_name  RMSE
# 0     INDUSTRIAL        ETS  0.04

# %%
# Dividir los datos en conjuntos de entrenamiento y prueba
train_size = int(len(merged_data) * 0.80)
train, test = merged_data.iloc[:train_size], merged_data.iloc[train_size:]

# Entrenar el modelo ETS con toda la serie temporal (train + test)
full_data = pd.concat([train, test])
y_full = full_data[target]

model_ETS_20_years = ExponentialSmoothing(endog=y_full, seasonal='add', seasonal_periods=12)
fit_model_ETS_20_years = model_ETS_20_years.fit()

# Proyección a 20 años
forecast_20_years_ETS = fit_model_ETS_20_years.forecast(steps=20)

# Visualizar las predicciones
plt.figure(figsize=(12, 6))
plt.plot(y_full.index, y_full, label='Actual Data')
plt.plot(np.arange(y_full.index[-1] + 1, y_full.index[-1] + 21), forecast_20_years_ETS, label='20-year Forecast', color='red')
plt.legend()
plt.title("20-year Forecast with ETS")
plt.xlabel("Year")
plt.ylabel(target)
plt.grid(True)
plt.show()

forecast_20_years_ETS
# Out:
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\ramon\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 52    85040.476459
# 53    86835.937960
# 54    84802.635775
# 55    84003.447781
# 56    85342.089639
# 57    85312.385131
# 58    85053.163104
# 59    83340.058736
# 60    83687.447630
# 61    84281.494674
# 62    84445.688441
# 63    82365.277696
# 64    85040.476459
# 65    86835.937960
# 66    84802.635775
# 67    84003.447781
# 68    85342.089639
# 69    85312.385131
# 70    85053.163104
# 71    83340.058736
# dtype: float64
